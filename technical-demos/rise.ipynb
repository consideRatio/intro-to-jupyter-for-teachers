# %% [markdown]
# # RISE
# ## About
# RISE enables you to view Jupyter Notebooks as PowerPoints.
#
# #### Keywords
# - PowerPoint
#
# ## Tutorial

# %%
from IPython.display import YouTubeVideo; YouTubeVideo('sXyFa_r1nxA')

# %% [markdown]
# ## Example
#
# [MyBinder - Short live demo](https://mybinder.org/v2/gh/binder-examples/jupyter-rise/master?filepath=index.ipynb)

# %% [markdown]
# ## Learn more
# For more technical details about RISE, see the [documentation](https://damianavila.github.io/RISE).
