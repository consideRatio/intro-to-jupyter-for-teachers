# %% [markdown]
# # NbGrader
#
# ## About
# NbGrader is all about notebooks as assignments. It helps in many ways.
# - Assignment creation
# - Assignment distribution infrastructure
# - Assignment grading
# - Assignment feedback
#
# #### Keywords
# - Assignments
#
# ## Tutorial

# %%
from IPython.display import YouTubeVideo; YouTubeVideo('5WUm0QuJdFw')
